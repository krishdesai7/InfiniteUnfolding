# %%
import os
os.environ['CUDA_VISIBLE_DEVICES']="3"
of_preds = dict()

# %%
import numpy as np
from omnifold import DataLoader, MLP, MultiFold
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import pickle

# %%
data_size = 10**4
sim_size = 10**5
mu_true, mu_gen = 0, -1

iterations = 5
dims = 1

rng = np.random.default_rng(1042)
truth = rng.normal(mu_true, 1, (data_size, 1))
gen = rng.normal(mu_gen, 1, (sim_size, 1))

with open("of_preds.pkl", "rb") as f:
    of_preds = pickle.load(f)

deltas_gen = dict()
deltas_of = dict()
# Out:
# Dictionary loaded from of_preds.pkl

# %%
def triangular_discriminator(p, q, bin_widths):
    """
    Triangular discriminator:
      0.5 * sum_i [((p_i - q_i)^2)/(p_i + q_i)] * bin_width_i * 1e3
    Bins where p_i + q_i = 0 contribute zero.
    """
    denom = p + q
    mask = denom > 0
    val = np.zeros_like(p)
    val[mask] = (p[mask] - q[mask])**2 / denom[mask]
    return 0.5 * np.sum(val * bin_widths) * 1e3

# %%
smearings = of_preds.keys()
for smearing in smearings:
    print(f"{smearing = }")
    
    data = truth * smearing
    sim = gen * smearing

    truth_train, truth_test, data_train, data_test = train_test_split(
            truth, data, test_size=0.2, random_state=42
    )

    gen_train, gen_test, sim_train, sim_test = train_test_split(
            gen, sim, test_size=0.2, random_state=42
    )

    nature_loader = DataLoader(
		  reco = data_train,
		  normalize=True)
    mc_loader = DataLoader(
		  reco = sim_train,
		  gen = gen_train,
		  normalize=True)
    reco_model = MLP(dims)
    gen_model = MLP(dims)

    omnifold = MultiFold(
        "RAN Comparison",
        reco_model,
        gen_model,
        nature_loader,
        mc_loader,
        batch_size = 512,
        niter = 5,
        epochs = 10,
        verbose = False,
        lr = 5e-5,
    )

    omnifold.Unfold()
    unfolded_weights = omnifold.reweight(gen_test, omnifold.model2, batch_size=1000)
    
    # Instead of skipping, we now append the results if the key already exists.
    if smearing in of_preds:
        of_preds[smearing].append([truth_test, gen_test, unfolded_weights])
    else:
        of_preds[smearing] = [[truth_test, gen_test, unfolded_weights]]
# Out:
# smearing = np.float64(0.0)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 15.750901222229004
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 8.66225814819336
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 15.763267517089844
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 8.662893295288086
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.699475288391113
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 8.660296440124512
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.765052795410156
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 8.663941383361816
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.761004447937012
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 8.66289234161377
# INFO: Dumping training history ...
# smearing = np.float64(5.0)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.430916786193848
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.472467422485352
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 15.575818061828613
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.381608009338379
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.771537780761719
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.400557994842529
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.807733535766602
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.364527702331543
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.634537696838379
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.362621784210205
# INFO: Dumping training history ...
# smearing = np.float64(10.0)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.768699645996094
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.66268253326416
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 16.41813850402832
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.301011562347412
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 16.525066375732422
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.350529670715332
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 16.62169075012207
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.360006809234619
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 16.710323333740234
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.40529203414917
# INFO: Dumping training history ...
# smearing = np.float64(15.0)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.150334358215332
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.384628772735596
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 15.318345069885254
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.268411159515381
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.553768157958984
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.217295169830322
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.585060119628906
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.126511096954346
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.568233489990234
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.010502338409424
# INFO: Dumping training history ...
# smearing = np.float64(20.0)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.217752456665039
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.40919303894043
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 15.644452095031738
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.256386756896973
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 16.00152015686035
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.3410234451293945
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 16.068248748779297
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.310141086578369
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 16.054040908813477
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.26902961730957
# INFO: Dumping training history ...
# smearing = np.float64(1.0526315789473684)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 14.515937805175781
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.447254180908203
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 17.22956085205078
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.249042987823486
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.806044578552246
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.255155086517334
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.797019004821777
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.286981105804443
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.8692626953125
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.260040283203125
# INFO: Dumping training history ...
# smearing = np.float64(2.1052631578947367)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.657670974731445
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.532793998718262
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 16.072189331054688
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.258784294128418
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.646407127380371
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.238778591156006
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.536766052246094
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.248810768127441
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.511950492858887
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.276492118835449
# INFO: Dumping training history ...
# smearing = np.float64(3.1578947368421053)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.512080192565918
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.3449859619140625
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1
# Last val loss 15.571736335754395
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.283937931060791
# INFO: Dumping training history ...
# ITERATION: 3
# RUNNING STEP 1
# Last val loss 15.678174018859863
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.244077205657959
# INFO: Dumping training history ...
# ITERATION: 4
# RUNNING STEP 1
# Last val loss 15.657881736755371
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.263561248779297
# INFO: Dumping training history ...
# ITERATION: 5
# RUNNING STEP 1
# Last val loss 15.594767570495605
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.18121862411499
# INFO: Dumping training history ...
# smearing = np.float64(4.2105263157894735)
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# INFO: Creating weights ...
# INFO: Creating pass reco flag ...
# INFO: Creating pass gen flag ...
# INFO: Normalizing sum of weights to 1000000 ...
# 171 training steps at reco and 312 steps at gen
# ITERATION: 1
# RUNNING STEP 1
# Last val loss 13.292828559875488
# INFO: Dumping training history ...
# RUNNING STEP 2
# Last val loss 7.339911937713623
# INFO: Dumping training history ...
# ITERATION: 2
# RUNNING STEP 1

# %%
sorted_keys = sorted([float(k) for k in of_preds.keys()])
print([f"{k:.3f}" for k in sorted_keys])

# %%
with open("of_preds.pkl", "wb") as f:
    pickle.dump(of_preds, f)

print("Dictionary saved to of_preds.pkl")
# Out:
# Dictionary saved to of_preds.pkl

# %%
for smearing in smearings:
    delta_gen_list = []
    delta_of_list = []
    for triplet in of_preds[smearing]:
        truth_test, gen_test, of_weights = triplet

        # Build histograms with density=True
        counts_truth, bin_edges = np.histogram(truth_test, density=True)
        counts_gen,   _         = np.histogram(gen_test, density=True)
        # Use the event-level weights when making the histogram for the reweighted gen.
        counts_of,    _         = np.histogram(gen_test, weights=np.atleast_2d(of_weights).T, density=True)
        
        bin_widths = np.diff(bin_edges)
    
        # Compute the triangular discriminators for this triplet
        delta_gen = triangular_discriminator(counts_gen, counts_truth, bin_widths)
        delta_of  = triangular_discriminator(counts_of,  counts_truth, bin_widths)
        
        # Append the individual delta values
        delta_gen_list.append(delta_gen)
        delta_of_list.append(delta_of)
        
    # Average the deltas over the K triplets for this smearing value
    deltas_gen[smearing] = (np.mean(delta_gen_list), np.std(delta_gen_list)/np.sqrt(len(delta_gen_list) - 1))
    deltas_of[smearing] = (np.mean(delta_of_list), np.std(delta_of_list)/np.sqrt(len(delta_of_list) - 1))

# %%
gen_means = [deltas_gen[k][0] for k in smearings]
gen_errs  = [deltas_gen[k][1] for k in smearings]

# Extract means and errors for the OF vs Truth data
of_means  = [deltas_of[k][0] for k in smearings]
of_errs   = [deltas_of[k][1] for k in smearings]

# Plot using error bars
plt.errorbar(gen_keys, gen_means, yerr=gen_errs, fmt='o', color='r', label='delta_gen')
plt.errorbar(of_keys, of_means, yerr=of_errs, fmt='o', color='g', label='delta_of')

# Add labels and legend
plt.xlabel("Smearing")
plt.ylabel("Triangular Discriminator")
plt.legend()
plt.show()

# Plot
plt.scatter(gen_x, gen_y, color='r', label='delta_gen')
plt.scatter(of_x, of_y, color='g', label='delta_of')

# Add labels and legend
plt.xlabel("Keys")
plt.ylabel("Values")
plt.legend()
plt.show()
