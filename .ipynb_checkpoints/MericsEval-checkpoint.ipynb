# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = np.load('training_metrics_compressed.npz')
disc_loss_avg = data['disc_loss_avg']
gen_loss_avg = data['gen_loss_avg']
baseline = data['baseline']
performance_metric = data['performance_metric']
substructure_variables = ['w', 'q', 'm', 'r', 'tau1s', 'tau2s']
n_epochs = 1000

# %%
pd.set_option('display.float_format', '{:.3f}'.format)
baseline_df = pd.DataFrame([baseline], columns=substructure_variables, index=['Baseline'])
performance_df = pd.DataFrame(performance_metric, columns=substructure_variables, index=pd.Index(range(1, n_epochs+1), name='Epoch'))
df = pd.concat([baseline_df, performance_df])
df['Total'] = results_df.sum(axis=1)
max_threshold = 1e3
results_df = results_df.map(lambda x: np.nan if abs(x) > max_threshold else x)

# %%
selected_epochs = ['Baseline'] + list(range(11, 31, 1))
display_df = df.loc[selected_epochs]

# %%
display_df
# Out:
#              w     q     m     r  tau1s  tau2s  Total
# Baseline 0.287 0.076 0.112 0.046  0.287  0.275  2.162
# 11       0.055 0.093 0.313 0.085  0.055  0.109  1.418
# 12       0.037 0.093 0.292 0.066  0.037  0.107  1.265
# 13       0.060 0.094 0.318 0.085  0.060  0.110  1.453
# 14       0.035 0.093 0.286 0.058  0.035  0.106  1.228
# 15       0.034 0.093 0.282 0.058  0.034  0.106  1.216
# 16       0.052 0.092 0.248 0.034  0.052  0.118  1.193
# 17       0.087 0.090 0.225 0.030  0.087  0.138  1.312
# 18       0.050 0.092 0.248 0.037  0.050  0.118  1.187
# 19       0.065 0.091 0.239 0.033  0.065  0.125  1.236
# 20       0.068 0.091 0.238 0.032  0.068  0.126  1.243
# 21       0.043 0.091 0.253 0.035  0.043  0.115  1.158
# 22       0.037 0.092 0.261 0.036  0.037  0.111  1.147
# 23       0.034 0.092 0.269 0.037  0.034  0.110  1.151
# 24       0.040 0.092 0.257 0.034  0.040  0.114  1.153
# 25       0.034 0.092 0.279 0.041  0.034  0.107  1.176
# 26       0.045 0.093 0.300 0.052  0.045  0.108  1.288
# 27       0.053 0.094 0.310 0.058  0.053  0.110  1.355
# 28       0.050 0.093 0.306 0.055  0.050  0.110  1.329
# 29       0.044 0.094 0.300 0.049  0.044  0.109  1.277
# 30       0.035 0.093 0.286 0.040  0.035  0.109  1.195

# %%
df[df.Total == df.Total.min()]
# Out:
#        w     q     m     r  tau1s  tau2s  Total
# 22 0.037 0.092 0.261 0.036  0.037  0.111  1.147

# %%
plt.figure(figsize=(10, 5))

# Discriminator Loss
plt.subplot(1, 2, 1)
plt.plot(disc_loss_avg[:30], label='Discriminator Loss')
plt.xlabel('epoch')
plt.legend()

# Generator Loss
plt.subplot(1, 2, 2)
plt.plot(gen_loss_avg[:30], label='Generator Loss')
plt.xlabel('epoch')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import tensorflow.keras.backend as K
from tensorflow.keras.layers import Input, Dense, BatchNormalization, concatenate, Layer, Lambda, Multiply, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.initializers import RandomNormal
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint

from sklearn.model_selection import train_test_split

# %%
#load and normalize the data
data = np.load('rawdata.npz')
substructure_variables = ['w', 'q', 'm', 'r', 'tau1s', 'tau2s']
data_streams = ['_true', '_true_alt', '_reco', '_reco_alt']
n_variables = len(substructure_variables)


normalize = True
    
for var_name in data.files:
    globals()[var_name] = data[var_name][:150000]
    
if normalize:
    for var_name in substructure_variables:
        mu = np.mean(globals()[var_name+data_streams[0]])
        sig = np.std(globals()[var_name + data_streams[0]])
        for stream in data_streams:
            globals()[var_name+stream] = (globals()[var_name+stream] - mu)/sig

# %%
N = len(m_true)

xvals_truth = np.array([np.concatenate([globals()[f"{var_name}_true_alt"], globals()[f"{var_name}_true"]]) for var_name in substructure_variables]).T
xvals_reco = np.array([np.concatenate([globals()[f"{var_name}_reco_alt"], globals()[f"{var_name}_reco"]]) for var_name in substructure_variables]).T
                    
yvals = np.concatenate([np.zeros(N, dtype=np.float32),np.ones(N, dtype=np.float32)])

X_train_truth, X_test_truth, X_train_reco, X_test_reco, Y_train, Y_test = train_test_split(
    xvals_truth, xvals_reco, yvals)

# %%
# Model configuration
gen_model_width = 100
gen_model_depth = 5
disc_model_width = 50
disc_model_depth = 3
dropout_rate = 0.0

# Generator model
def build_generator(input_shape):
    gen_input = Input(shape=(input_shape,))
    x = gen_input
    
    # Initialize kernel
    kernel_init = RandomNormal(mean=0.0, stddev=0.2)
    
    # Hidden layers
    for _ in range(gen_model_depth):
        x = Dense(gen_model_width, activation='relu', use_bias=False, kernel_initializer=kernel_init if _ == 0 else None)(x)
        x = BatchNormalization()(x)
        x = Dropout(dropout_rate)(x)

    # Output layer
    x = Dense(1, activation='softplus', use_bias=False)(x)
    outputs = Lambda(lambda x: x / K.log(2.0))(x)
    return Model(inputs=gen_input, outputs=outputs)

model_generator = build_generator(xvals_truth.shape[1])
# Out:
# 2024-04-05 18:32:12.432189: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13252 MB memory:  -> device: 0, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1a:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.433989: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13786 MB memory:  -> device: 1, name: Tesla V100-SXM2-16GB, pci bus id: 0000:1b:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.435107: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:2 with 13786 MB memory:  -> device: 2, name: Tesla V100-SXM2-16GB, pci bus id: 0000:3d:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.436621: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:3 with 13786 MB memory:  -> device: 3, name: Tesla V100-SXM2-16GB, pci bus id: 0000:3e:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.438060: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:4 with 13786 MB memory:  -> device: 4, name: Tesla V100-SXM2-16GB, pci bus id: 0000:88:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.439124: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:5 with 13786 MB memory:  -> device: 5, name: Tesla V100-SXM2-16GB, pci bus id: 0000:89:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.440117: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:6 with 13786 MB memory:  -> device: 6, name: Tesla V100-SXM2-16GB, pci bus id: 0000:b2:00.0, compute capability: 7.0
# 2024-04-05 18:32:12.441145: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1928] Created device /job:localhost/replica:0/task:0/device:GPU:7 with 13786 MB memory:  -> device: 7, name: Tesla V100-SXM2-16GB, pci bus id: 0000:b3:00.0, compute capability: 7.0

# %%
model_generator.load_weights('InfiniteUnfolding/model_checkpoints/generator_epoch-0020.weights.h5')

# %%
weights = model_generator.predict(X_test_truth[Y_test == 0], verbose=0).flatten()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1712367231.018195  460253 service.cc:145] XLA service 0x7feee80087c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1712367231.018232  460253 service.cc:153]   StreamExecutor device (0): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018241  460253 service.cc:153]   StreamExecutor device (1): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018244  460253 service.cc:153]   StreamExecutor device (2): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018249  460253 service.cc:153]   StreamExecutor device (3): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018255  460253 service.cc:153]   StreamExecutor device (4): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018261  460253 service.cc:153]   StreamExecutor device (5): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018267  460253 service.cc:153]   StreamExecutor device (6): Tesla V100-SXM2-16GB, Compute Capability 7.0
# I0000 00:00:1712367231.018272  460253 service.cc:153]   StreamExecutor device (7): Tesla V100-SXM2-16GB, Compute Capability 7.0
# 2024-04-05 18:33:51.026180: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:268] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2024-04-05 18:33:54.498793: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:465] Loaded cuDNN version 8907
# I0000 00:00:1712367234.637879  460253 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.

# %%
fig, axs = plt.subplots(3, 2, figsize=(16, 18))
axs = axs.flatten()
nbins = 30
density = True

for i, var_name in enumerate(substructure_variables):
    X = X_test_truth[:, i]*np.std(globals()[var_name + '_true']) + np.mean(globals()[var_name + '_true'])
    bins = np.linspace(X.min(), X.max(), nbins)
    
    axs[i].hist(X[Y_test == 1], bins=bins, alpha=0.5, label="truth", density=density, zorder=-1)
    axs[i].hist(X[Y_test == 0], bins=bins, alpha=0.5, label="gen", density=density, zorder=0)
    axs[i].hist(X[Y_test == 0], bins=bins, weights=weights,
                histtype="step", color="red", ls=":", lw=2, label="weighted gen", density=density, zorder=1)
    
    axs[i].legend(fontsize=12)
    axs[i].set_ylabel("Density")
    axs[i].set_xlabel(var_name)

for j in range(i + 1, len(axs)):
    axs[j].axis('off')

plt.tight_layout()
plt.show()
